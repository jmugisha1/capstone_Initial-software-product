# %%
import numpy as np
import pandas as pd
from sentence_transformers import SentenceTransformer
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.regularizers import l1_l2
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, classification_report
from tensorflow.keras.optimizers import Adam
import pickle

# %%
# Load data
df = pd.read_csv('/content/drive/MyDrive/capstone/diseases.csv')

# %%
df = df.drop(['category', 'category_type'], axis=1)

# Drop rows with NaN in either column
df = df.dropna(subset=['symptoms', 'disease_name'])

# Clean symptoms - convert to string and clean
df['symptoms_clean'] = df['symptoms'].astype(str).str.replace(';', ' ').str.strip()

# Remove any rows that became 'nan' string or empty
df = df[df['symptoms_clean'] != 'nan']
df = df[df['symptoms_clean'] != '']
df = df.reset_index(drop=True)

print(f"Clean data: {len(df)} rows")
# Out:
# Clean data: 9332 rows

# %%
# ClinicalBERT embeddings
clinicalbert = SentenceTransformer('emilyalsentzer/Bio_ClinicalBERT')
df['symptoms_clean'] = df['symptoms'].str.replace(';', ' ')
df = df[df['symptoms_clean'].str.strip() != '']  # Remove empty strings
df = df[df['symptoms_clean'] != 'nan']  # Remove 'nan' strings

X = clinicalbert.encode(df['symptoms_clean'].tolist(), show_progress_bar=True, batch_size=64)

label_encoder = LabelEncoder()
y = label_encoder.fit_transform(df['disease_name'])
num_classes = len(np.unique(y))
# Out:
# WARNING:sentence_transformers.SentenceTransformer:No sentence-transformers model found with name emilyalsentzer/Bio_ClinicalBERT. Creating a new one with mean pooling.
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: emilyalsentzer/Bio_ClinicalBERT
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# cls.predictions.transform.dense.bias       | UNEXPECTED |  |
# cls.predictions.decoder.weight             | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |  |
# cls.seq_relationship.weight                | UNEXPECTED |  |
# cls.seq_relationship.bias                  | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |  |
# cls.predictions.transform.dense.weight     | UNEXPECTED |  |
# cls.predictions.bias                       | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Batches:   0%|          | 0/146 [00:00<?, ?it/s]

# %%
model = Sequential([
    Input(shape=(768,)),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(num_classes, activation='softmax')
])

model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Train with smaller batches
history = model.fit(X, y, epochs=100, batch_size=32, verbose=1)
# Out:
# Epoch 1/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.0000e+00 - loss: 9.1618
# Epoch 2/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 3.0503e-05 - loss: 9.1439
# Epoch 3/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 4.1311e-04 - loss: 8.9754
# Epoch 4/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0021 - loss: 8.3592
# Epoch 5/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0083 - loss: 7.4589
# Epoch 6/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0372 - loss: 6.2339
# Epoch 7/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0911 - loss: 4.8688
# Epoch 8/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.2024 - loss: 3.6933
# Epoch 9/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.2915 - loss: 3.0050
# Epoch 10/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.3649 - loss: 2.5858
# Epoch 11/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.4162 - loss: 2.2997
# Epoch 12/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.4596 - loss: 2.0744
# Epoch 13/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.4988 - loss: 1.9176
# Epoch 14/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5084 - loss: 1.8201
# Epoch 15/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5236 - loss: 1.7714
# Epoch 16/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5419 - loss: 1.6975
# Epoch 17/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5496 - loss: 1.6445
# Epoch 18/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5683 - loss: 1.5702
# Epoch 19/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5771 - loss: 1.5278
# Epoch 20/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5813 - loss: 1.5197
# Epoch 21/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5777 - loss: 1.5027
# Epoch 22/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5829 - loss: 1.4810
# Epoch 23/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5897 - loss: 1.4217
# Epoch 24/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6055 - loss: 1.3838
# Epoch 25/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6045 - loss: 1.3747
# Epoch 26/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6023 - loss: 1.3804
# Epoch 27/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5973 - loss: 1.3617
# Epoch 28/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6058 - loss: 1.3463
# Epoch 29/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6120 - loss: 1.3203
# Epoch 30/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6056 - loss: 1.3438
# Epoch 31/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6017 - loss: 1.3189
# Epoch 32/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6057 - loss: 1.3174
# Epoch 33/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6052 - loss: 1.3154
# Epoch 34/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6073 - loss: 1.3031
# Epoch 35/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6173 - loss: 1.2562
# Epoch 36/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6111 - loss: 1.2824
# Epoch 37/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6140 - loss: 1.2703
# Epoch 38/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6124 - loss: 1.2483
# Epoch 39/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6117 - loss: 1.2661
# Epoch 40/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6059 - loss: 1.2798
# Epoch 41/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6226 - loss: 1.2401
# Epoch 42/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6152 - loss: 1.2461
# Epoch 43/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6116 - loss: 1.2406
# Epoch 44/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6134 - loss: 1.2358
# Epoch 45/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6185 - loss: 1.2338
# Epoch 46/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6095 - loss: 1.2473
# Epoch 47/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6151 - loss: 1.2225
# Epoch 48/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6131 - loss: 1.2091
# Epoch 49/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6165 - loss: 1.2234
# Epoch 50/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6236 - loss: 1.1960
# Epoch 51/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6271 - loss: 1.1708
# Epoch 52/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6160 - loss: 1.1978
# Epoch 53/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6194 - loss: 1.2004
# Epoch 54/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6216 - loss: 1.1862
# Epoch 55/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6181 - loss: 1.1885
# Epoch 56/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6163 - loss: 1.1967
# Epoch 57/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6211 - loss: 1.1882
# Epoch 58/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6225 - loss: 1.1755
# Epoch 59/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6176 - loss: 1.1775
# Epoch 60/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6290 - loss: 1.1462
# Epoch 61/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6154 - loss: 1.1833
# Epoch 62/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6179 - loss: 1.1800
# Epoch 63/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6351 - loss: 1.1193
# Epoch 64/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6270 - loss: 1.1509
# Epoch 65/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6231 - loss: 1.1575
# Epoch 66/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6131 - loss: 1.1618
# Epoch 67/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6178 - loss: 1.1674
# Epoch 68/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6190 - loss: 1.1769
# Epoch 69/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6167 - loss: 1.1643
# Epoch 70/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6179 - loss: 1.1647
# Epoch 71/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6155 - loss: 1.1741
# Epoch 72/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6095 - loss: 1.1880
# Epoch 73/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6143 - loss: 1.1645
# Epoch 74/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6218 - loss: 1.1237
# Epoch 75/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6314 - loss: 1.1273
# Epoch 76/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6173 - loss: 1.1387
# Epoch 77/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6262 - loss: 1.1243
# Epoch 78/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6211 - loss: 1.1340
# Epoch 79/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6196 - loss: 1.1339
# Epoch 80/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6184 - loss: 1.1410
# Epoch 81/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6201 - loss: 1.1333
# Epoch 82/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6168 - loss: 1.1563
# Epoch 83/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6277 - loss: 1.1103
# Epoch 84/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6182 - loss: 1.1279
# Epoch 85/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6203 - loss: 1.1302
# Epoch 86/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6209 - loss: 1.1384
# Epoch 87/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6174 - loss: 1.1478
# Epoch 88/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6280 - loss: 1.1172
# Epoch 89/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6183 - loss: 1.1490
# Epoch 90/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6165 - loss: 1.1412
# Epoch 91/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6264 - loss: 1.0948
# Epoch 92/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6102 - loss: 1.1465
# Epoch 93/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6166 - loss: 1.1327
# Epoch 94/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6216 - loss: 1.1127
# Epoch 95/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6197 - loss: 1.1184
# Epoch 96/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6258 - loss: 1.1073
# Epoch 97/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6124 - loss: 1.1047
# Epoch 98/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6272 - loss: 1.1000
# Epoch 99/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6175 - loss: 1.1230
# Epoch 100/100
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6282 - loss: 1.0864

# %%
# Evaluate on training data
y_pred = model.predict(X).argmax(axis=1)
accuracy = np.mean(y_pred == y)
f1 = f1_score(y, y_pred, average='macro')

print(f"\nAccuracy: {accuracy:.3f}")
print(f"F1-Score: {f1:.3f}")
# Out:
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
#
# Accuracy: 0.651
# F1-Score: 0.611

# %%
# Save # Save the label encoder
model.save('/content/drive/MyDrive/capstone/model/disease_classifier.h5')

with open('/content/drive/MyDrive/capstone/model/label_encoder.pkl', 'wb') as f:
    pickle.dump(label_encoder, f)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
